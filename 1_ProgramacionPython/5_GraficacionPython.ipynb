# %% [markdown]
# <a href="https://colab.research.google.com/github/santiagokarla/FisicaComputacional_2027-1_8270/blob/main/1_ProgramacionPython/5_GraficacionPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1 align="center">Física Computacional.</h1>
# <h1 align="center">Semestre 2027-1</h1>
#
# <h2>Sergio A. Alcalá Corona </h2>
#
# ---
# ### Rodrigo Vega Vilchis
# ### Joel Gómez Uribe
# ---

# %% [markdown]
# <h1 align="center">Programación para la física computacional</h1>
#
# ## 1.1.5 Graficación con Python.
#
# ---
# $\;$
# En este *Notebook* expondremos algunos ejemplos de como elaborar gráficas en Python con la biblioteca **Matplotlib**, una de las más usadas.

# %% [markdown]
# ### Uso básico

# %% [markdown]
# Es posible dibujar gráficas dentro de *Python*, usando la biblioteca **matplotlib** (que hay que tener instalada).

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# El comando principal de **matplotlib** es **`plot`**.

# %%
y = [ 1.0, 2.4, 1.7, 0.3, 0.6, 1.8]
plt.plot(y,'.')

# %%
plt.plot(y)
plt.plot(y,'r.')

# %% [markdown]
# Acepta uno o dos listas (o vectores de *numpy*), que corresponden a los valores de las coordenadas $x$ y $y$ de una gráfica 2D.
#
# Así en general, con tener una lista de números (enteros o flotantes) y pasarla como argumento de la función **`plot`** es suficiente para generar una gráfica. La lista de números  corresponderá a las coordenadas en $y$ mientras que los valores en $x$ serán los asociados su posición en la lista.
#
#
# Por ejemplo, si queremos graficar los cuadrados de los números de 1 a 10, podemos hacer:

# %%
import numpy as np

x = np.arange(10)
y = x*x

plt.plot(x,y)

# %%
y
# Out:
# array([ 0,  1,  4,  9, 16, 25, 36, 49, 64, 81])

# %%
plt.plot(x, y, 'o')

# %%
y = [ i ** 2 for i in range(10)]
plt.plot(y)
plt.plot(y, 'ro')

# %% [markdown]
# **Nota:** Usar la biblioteca de `numpy` es _casi obligatorio_ para elaborar gráficas de funciones.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(10)
y = x*x

plt.plot(x,y);

# %%
x = np.arange(1,11)
y = x*x
plt.plot(x,y,'o-'); # o- = circulitos con línea

# %% [markdown]
# Una mucho mejor forma de graficar es indicar los valores de la abscisa y ordenada de forma independiente.
#
# **OJO**: el número de elementos de los arreglos del eje _x_ y del eje _y_ **deben ser iguales**.

# %%
x = np.linspace(-2*np.pi,2*np.pi,100)
fx = np.cos(x)
plt.plot(x,fx)
plt.plot(x,fx,'g.')

# %%
x
# Out:
# array([-6.28318531, -6.15625227, -6.02931923, -5.9023862 , -5.77545316,
#        -5.64852012, -5.52158709, -5.39465405, -5.26772102, -5.14078798,
#        -5.01385494, -4.88692191, -4.75998887, -4.63305583, -4.5061228 ,
#        -4.37918976, -4.25225672, -4.12532369, -3.99839065, -3.87145761,
#        -3.74452458, -3.61759154, -3.4906585 , -3.36372547, -3.23679243,
#        -3.10985939, -2.98292636, -2.85599332, -2.72906028, -2.60212725,
#        -2.47519421, -2.34826118, -2.22132814, -2.0943951 , -1.96746207,
#        -1.84052903, -1.71359599, -1.58666296, -1.45972992, -1.33279688,
#        -1.20586385, -1.07893081, -0.95199777, -0.82506474, -0.6981317 ,
#        -0.57119866, -0.44426563, -0.31733259, -0.19039955, -0.06346652,
#         0.06346652,  0.19039955,  0.31733259,  0.44426563,  0.57119866,
#         0.6981317 ,  0.82506474,  0.95199777,  1.07893081,  1.20586385,
#         1.33279688,  1.45972992,  1.58666296,  1.71359599,  1.84052903,
#         1.96746207,  2.0943951 ,  2.22132814,  2.34826118,  2.47519421,
#         2.60212725,  2.72906028,  2.85599332,  2.98292636,  3.10985939,
#         3.23679243,  3.36372547,  3.4906585 ,  3.61759154,  3.74452458,
#         3.87145761,  3.99839065,  4.12532369,  4.25225672,  4.37918976,
#         4.5061228 ,  4.63305583,  4.75998887,  4.88692191,  5.01385494,
#         5.14078798,  5.26772102,  5.39465405,  5.52158709,  5.64852012,
#         5.77545316,  5.9023862 ,  6.02931923,  6.15625227,  6.28318531])

# %%
plt.grid?

# %%
plt.plot(x,fx)
plt.grid()

# %%
plt.plot(x,fx)

plt.axhline(y = 0.0, xmin = 0.0, color = 'black')
plt.axvline(x = 0.0, ymin = 0.0, color = 'black')
plt.grid()

# %% [markdown]
# Puedes colocar varias funciones en la misma gráfica y para darle diferentes estilos, es posible usar una notación abreviada para seleccionar distintos tipos de líneas y/o  colores.
#
# Calculemos la  función $\sin(x)$

# %%
fx1 = np.sin(x)

# %% [markdown]
# En la siguiente gráfica $\sin(x)$ tiene la opción **`go`**, donde la `g` indica el color de línea, en este caso verde, y la `o` que el marcador para dibujar el seno serán puntos.
#
# Mientras que el $\cos(x)$, tiene la opción **`r--`** donde la `r` indica que la línea será de color rojo y el guión doble `--` señala que la línea será punteada.

# %%
plt.plot(x,fx,'r--')
plt.plot(x,fx1,'go')

plt.axhline(y = 0.0, xmin = 0.0, color = 'black')
plt.axvline(x = 0.0, ymin = 0.0, color = 'black')
plt.grid()

# %% [markdown]
# Para mayor información sobre los colores y los estilos de línea consulta el manual de la función `plt.plot`, recuerda que esto lo puedes hacer ejecutando en una celda individual **`plt.plot?`**.

# %%
plt.plot?

# %% [markdown]
# La opción abreviada sólo tiene disponible 7 colores si queremos usar otros colores debemos indicarlo con el argumento `color = ` para consultar los nombres de los colores disponibles dale [click aquí.](https://matplotlib.org/3.1.1/gallery/color/named_colors.html#sphx-glr-gallery-color-named-colors-py) Incluso podemos ingresar el color en el sistema _RBG_ o _CMK_.
#
# Además podemos indicar el estilo de línea con argumentos `linestyle = ` o `marker`, o modificar el tamaño del marcador o el ancho de línea con `markersize` y `linewidth`, respectivamente.
#
# Para colocar las etiquetas de los ejes y del título de la gráfica usamos `plt.title`, `plt.xlabel` y `plt.ylabel`.

# %%
plt.plot(x,fx,color='olive', linestyle=':',linewidth=3)
plt.plot(x,fx1,color='#a41b81',marker='+', markersize=9,linestyle='None')


plt.title("Funciones periodicas")
plt.xlabel("x")
plt.ylabel("f(x)")

plt.axhline(y = 0.0, xmin = 0.0, color = 'black')
plt.axvline(x = 0.0, ymin = 0.0, color = 'black')
plt.grid()

# %% [markdown]
# Cuando queremos colocar una etiqueta a las funciones graficadas lo hacemos con el argumento `label` y al final llamamos a la función `plt.legend()`.
#
# En el caso que tenemos la opción `loc = ` dentro de `plt.legend` indica donde se colocará el texto de las etiquetas. Por default `matplotlib` tratará de colocar los letreros en el mejor espacio (`loc = 0`).

# %%
plt.plot(x,fx,color='olive', ls='-',lw=2,label='cos(x)')
plt.plot(x,fx1,color='#a41b81',marker='.',ms=9,ls='None',label='sen(x)')

plt.title("Funciones periodicas")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend(loc=2)

plt.axhline(y = 0.0, xmin = 0.0, color = 'black')
plt.axvline(x = 0.0, ymin = 0.0, color = 'black')
plt.grid()

# %% [markdown]
# Puedes optimizar la estetica y estilo (_**pimpear**_) de tu gráfica con mucho detalle.

# %%
plt.figure(figsize=(7,7)) # Modifica el tamaño de la gráfica. Esta dado en pulgadas.

plt.plot(x,fx,color='olive', ls='-',lw=2,label='cos(x)')
plt.plot(x,fx1,color='#a41b81',marker='.',ms=9,ls='None',label='sen(x)')

plt.title("Funciones periodicas")
plt.xlabel("x")
plt.ylabel("f(x)")

plt.legend(loc=2)

plt.grid(True) # Dibuja en el fondo una rejilla  gris claro

# Colocar un texto en la posición señalada
plt.text(-np.pi/2, -1.1, 'Minimo',horizontalalignment='center', verticalalignment='baseline')

plt.annotate('Maximo',(np.pi/2,1),xytext=(2.5,0.9),
             arrowprops=dict(facecolor='black',width=1,headwidth=5,shrink=0.05),
             horizontalalignment='left') # Hace una anotación en el lugar indicado, utiliza una flecha para señalar la posición.

plt.xlim(-np.pi,np.pi) # Limita la gráfica sobre el eje x

yt = np.arange(-1,1.5,0.5) # Este arreglo sirve generar nuevas marcas sobre el eje y

plt.yticks(yt) # Con esta función se colocan las nuevas marcas sobre el eje y

xt = [-np.pi,0,np.pi] # Este arreglo sirve generar nuevas marcas sobre el eje x

xt_labels = ['-pi','0','pi'] # Sobre las marcas se pueden colocar texto

plt.xticks(xt,xt_labels) # Con esta función se colocan las nuevas marcas sobre el eje y

plt.savefig('funciones.png') # Guarda la gráfica como un archivo independiente. Puedes utilizar la extensión .jpg, .pdf entre otras.

# %% [markdown]
# Para un mejor acabado de la gráfica puedes utilizar $\LaTeX$, para ello primero hay que utilizar la siguiente instrucción.

# %%
# import matplotlib as mpl
# mpl.rc('text', usetex = True)

# %% [markdown]
# Cuando necesites utilizar algún simbolo de $\LaTeX$ escríbelo entre dos signos de dinero `$` tal como lo utilizarías dentro de un archivo `.tex`.
#
# En la mayoría de las funciones para las etiquetas la opción `fontsize` es suficiente para modificar el tamaño de la tipografía.

# %%
plt.figure(figsize=(7,7))

plt.plot(x, fx, color='olive', ls='-', lw=2, label=r'$\cos(x)$')

plt.plot(x,fx1,color='#a41b81',marker='.',ms=9,ls='None',label=r'$\sin(x)$')

plt.title("Funciones periodicas",fontsize=20)
plt.xlabel("$x$",fontsize=18)
plt.ylabel("$f(x)$",fontsize=18)
plt.legend(loc=2)

plt.grid(True)
plt.text(-np.pi/2, -1.1, 'Mínimo',horizontalalignment='center',
         verticalalignment='baseline')
plt.annotate('Máximo',(np.pi/2,1),xytext=(2.5,0.9),
             arrowprops=dict(facecolor='black',width=1,headwidth=5,shrink=0.05),
             horizontalalignment='left')

plt.xlim(-np.pi,np.pi)

yt = np.arange(-1,1.5,0.5)
plt.yticks(yt,fontsize=18)
xt = [-np.pi,0,np.pi]
xt_labels = [r'$-\pi$','$0$' ,r'$\pi$']
plt.xticks(xt,xt_labels,fontsize=18)

plt.savefig('FPeridocas.pdf')

# %% [markdown]
# ### Ejemplo: Suceción de Fibonacci
#
# Anteriormente hicimos un porgrama que calculaba los valores de la sucesión de Fibonacci.
# Al imprimir la diferencia, entre el número (_aureo_) $\phi$ y los valores a los que $\dfrac{f_{n+1}}{f_n}$ se iba acercando, notamos una especie de oscilación.

# %%
import math as mt

phi = (1 + mt.sqrt(5))/2
f1,f2 = 1,1

Fibonacci = []
Time = []

t = 0.0

n = 1000000
print("Para n =",n)

while f2 <= n:

    fn = f2/f1
    Fibonacci.append(fn)
    Time.append(t)
    t = t + 1

    print("la diferencia con phi es: ",phi-fn)
    f1,f2 = f2,f1+f2
# Out:
# Para n = 1000000
# la diferencia con phi es:  0.6180339887498949
# la diferencia con phi es:  -0.3819660112501051
# la diferencia con phi es:  0.1180339887498949
# la diferencia con phi es:  -0.04863267791677184
# la diferencia con phi es:  0.018033988749894814
# la diferencia con phi es:  -0.0069660112501050975
# la diferencia con phi es:  0.0026493733652794837
# la diferencia con phi es:  -0.0010136302977241662
# la diferencia con phi es:  0.00038692992636546464
# la diferencia con phi es:  -0.00014782943192326314
# la diferencia con phi es:  5.6460660007306984e-05
# la diferencia con phi es:  -2.15668056606777e-05
# la diferencia con phi es:  8.237676933475768e-06
# la diferencia con phi es:  -3.1465286196574738e-06
# la diferencia con phi es:  1.2018646489142526e-06
# la diferencia con phi es:  -4.590717870289751e-07
# la diferencia con phi es:  1.7534976959332482e-07
# la diferencia con phi es:  -6.697765919660981e-08
# la diferencia con phi es:  2.5583188456579364e-08
# la diferencia con phi es:  -9.771908393574336e-09
# la diferencia con phi es:  3.732536946188247e-09
# la diferencia con phi es:  -1.4257022229458016e-09
# la diferencia con phi es:  5.445699446937624e-10
# la diferencia con phi es:  -2.0800716704627575e-10
# la diferencia con phi es:  7.945177848966978e-11
# la diferencia con phi es:  -3.034772433352373e-11
# la diferencia con phi es:  1.159183860011126e-11
# la diferencia con phi es:  -4.427569422205124e-12
# la diferencia con phi es:  1.6913137557139635e-12

# %% [markdown]
# Esto se puede entender mejor, al grficar los valor de la sucesión $f_n$ vs $n$.

# %%
plt.figure(figsize=(9,6))

plt.axhline(y = phi, xmin = 0.0, color = 'blue', linestyle='--', linewidth = 1)
plt.text(-3.5, phi, r'$\phi$', size=17)

plt.plot(Time,Fibonacci, alpha=0.5)
plt.plot(Time,Fibonacci,'r.')

plt.grid()

plt.axhline(y = 1.0, xmin = 0.0, color = 'black')

# %% [markdown]
# ### Gráficas _semilogarítmica_ y _log-log_

# %% [markdown]
# Vamos a graficar la función $f(x) = x^2$ en el intervalo $[1,100)$. Esta función nos servirá para introduccir las gráficas semilog y loglog.
#
# Definimos el intervalo y luego aplicamos la función cuadrática

# %%
x2 = np.linspace(1,1000)
fx2 = x2**2

# %% [markdown]
# La gráfica que por defecto nos arroja es la siguiente:

# %%
plt.figure(figsize=(9,6))

plt.plot(x2,fx2)

plt.title("Una función exponencial $f(x) = x^2$",fontsize=15)
plt.xlabel("$x$",fontsize=15)
plt.ylabel("$f(x)$",fontsize=15)

plt.axhline(y = 0.0, xmin = 0.0, color = 'black')
plt.axvline(x = 0.0, ymin = 0.0, color = 'black')
plt.grid()

# %% [markdown]
# dado que los valores arrojados por la función cuadrática son enormes comparados con los valores de intervalo de entrada de la función, sobre el eje $y$ dominan los millones. Una manera de ver completo el eje $y$ es verlo en escala logarítmica. En este caso en vez de `plot` usamos `semilogy` (también se puede aplicar sobre el eje $x$ con `semilogx`).

# %%
plt.figure(figsize=(9,6))

plt.semilogy(x2,fx2)   #grafica semilog (el eje y esta en escala logaritmica)

plt.title(r"Gráfica semilog en $y$ de $f(x) = x^2$",fontsize=15)
plt.xlabel("$x$",fontsize=15)
plt.ylabel("$f(x)$",fontsize=15)

plt.axhline(y = 0.0, xmin = 0.0, color = 'black')
plt.axvline(x = 0.0, ymin = 0.0, color = 'black')
plt.grid()

# %% [markdown]
# Si queremos aplicar la escala logaritmica a los dos ejes usamos `loglog`.

# %%
import numpy as np
import matplotlib.pyplot as plt

x2 = np.linspace(1,1000)
fx2 = x2**2

# %%
plt.figure(figsize=(9,6))

plt.loglog(x2,fx2)   #grafica log-log (ambos ejes estan en escala logaritmica)

plt.title(r"Gráfica log-log de $f(x) = x^2$",fontsize=15)
plt.xlabel("$x$",fontsize=15)
plt.ylabel("$f(x)$",fontsize=15)

plt.axhline(y = 0.0, xmin = 0.0, color = 'black')
plt.axvline(x = 0.0, ymin = 0.0, color = 'black')
plt.grid()

# %% [markdown]
# ### Gráficas en sistema de coordenadas polares

# %% [markdown]
# Con la función `polar` pueden obtener gráficas en el sistema de coordenadas polar. El primer argumento corresponde a los valores de $\theta$ mientras que el segundo corresponde a los valores de $r$.
#
# Por ejemplo, la función $r(\theta) = \theta$ en el intervalo $[0,2\pi)$ se vería como:

# %%
x = np.linspace(0,2*np.pi)

# %% [markdown]
# **OJO** la función `plt.polar` trabaja en radianes (al igual que todas las funciones trigonométricas en `numpy`).

# %%
plt.figure(figsize=(9,6))

plt.polar(x,x)

plt.title("Gráfica en coordenadas polares",fontsize=15)
# Out:
# Text(0.5, 1.0, 'Gráfica en coordenadas polares')

# %% [markdown]
# ### Histogramas

# %% [markdown]
# Otra de las gráficas que más usarán será el histrograma. La manera de obtenerlo es muy sencillo con la función `plt.hist`.
#
# Para generar números 1000 aleatorios con la distribución normal lo hacemos con la siguiente función:

# %%
aleatorios = np.random.normal(size=1000)

# %%
plt.figure(figsize=(9,7)) # tamaño de al grafica.
                          # El primer numero da el ancho y el segundo da lo alto.

plt.hist(aleatorios,bins=31,histtype='bar', align='left',color='royalblue',rwidth=0.9)

plt.title('Histograma normalizado de números aleatorios generados con la distibución normal',fontsize=15)
plt.ylabel('Frecuencia',fontsize=15)
plt.xlabel("valores",fontsize=15)

plt.grid()

# %% [markdown]
# ### Subgráficas

# %% [markdown]
# Las subgráficas es otra de las funciones más útiles y usadas. Con esto se puede comparar diversas gráficas. En este caso `subplot(rcn)` es la función que deben ocupa. Lo que nos puede generar una matrix donde `r` es el número de renglones, `c` el número de columnas y `n` es el número de la gráfica. La numeración de las gráficas empieza desde la esquina superior izquierda y continua como normalmente leemos, de izquierda a derecha y de arriba hacia abajo.
#
# En el siguiente ejemplo, mostraremos la función $\sin(x)$ en el intervalo $[0,2\pi)$ y sus dos primeros armónicos  y en la última subgráfica los sumaremos.

# %%
x = np.linspace(0,2*np.pi,num=200)
f1 = np.sin(x)
f2 = np.sin(2*x)
f3 = np.sin(3*x)
f4 = f1+f2+f3

# %%
plt.figure(figsize=(9,6))

plt.subplot(221)
plt.plot(x,f1)
plt.title(r'$f_1 = \sin(x)$',fontsize=13)
plt.ylabel("$f(x)$",fontsize=11)
# plt.axhline(y = 0.0, xmin = 0.0, color = 'black')
# plt.axvline(x = 0.0, ymin = 0.0, color = 'black')
# plt.grid()

plt.subplot(222)
plt.plot(x,f2)
plt.title(r'$f_2 = \sin(2x)$',fontsize=13)
# plt.axhline(y = 0.0, xmin = 0.0, color = 'black')
# plt.axvline(x = 0.0, ymin = 0.0, color = 'black')
plt.grid()


plt.subplot(223)
plt.plot(x,f3)
plt.title(r'$f_2 = \sin(4x)$',fontsize=13)
plt.xlabel(r'$x$',fontsize=13)
plt.ylabel("$f(x)$",fontsize=11)
plt.axhline(y = 0.0, xmin = 0.0, color = 'black')
plt.axvline(x = 0.0, ymin = 0.0, color = 'black')
# plt.grid()

plt.subplot(224)
plt.plot(x,f4)
plt.title('$f_4 = f_1+f_2+f_3$',fontsize=13)
plt.xlabel('$x$',fontsize=13)
plt.axhline(y = 0.0, xmin = 0.0, color = 'black')
plt.axvline(x = 0.0, ymin = 0.0, color = 'black')
plt.grid()

plt.tight_layout() # con esta instrucción se autoajustan los espacios entre las gráficas mismas y también con los bordes de la imagen

# %% [markdown]
# Aqui otro ejemplo de varias gráficas:

# %%
import math as mt

def f(t):
    """Oscilacion amortiguada"""
    # c = mt.cos(2*mt.pi*t)
    # e = mt.exp(-t)
    c = np.cos(2*np.pi*t)
    e = np.exp(-t)
    return c*e

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)
t3 = np.arange(0.0, 2.0, 0.01)

plt.figure(figsize=(9,6))

#Es una tabla de 2 renglones y columna (21#)
#Por lo tanto solo hay 2 espacios para poner figuras!

plt.subplot(211) # Grafica uno
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k--', markerfacecolor='green')
plt.grid(True)
plt.title('Amortiguacion de oscilaciones')
plt.ylabel('Amortiguada')

plt.subplot(212) # Grafica dos

# plt.plot(t3, mt.cos(2*mt.pi*t3), 'r.')
plt.plot(t3, np.cos(2*np.pi*t3), 'r.')

plt.grid(True)
plt.xlabel('tiempo $t$ (s)')
plt.ylabel('No amortiguada')


# plt.show()   ### Si esto fuera un script de Python hay que llamar este commando para poder ver la grafica.
# Out:
# Text(0, 0.5, 'No amortiguada')

# %% [markdown]
# Finalmente, es importante señalar que si queremos hacer nuestras gráficas desde un **Script de Python** es necesarios llamar el comando _**show()**_ con `plt.show()` dentro del script para poder visualizar las gráficas.

# %% [markdown]
# <!-- ### Gráficas en 2D -->
# ### Scatter plots

# %%
import numpy as np
import os
os.makedirs("data", exist_ok=True)

# inventamos datos tipo diagrama HR de estrellas
# 100 estrellas, temperatura 3000 a 12000, magnitud -5 a 15
temp = np.random.uniform(3000, 12000, 100)
mag = np.random.uniform(-5, 15, 100)
datos = np.column_stack((temp, mag))
np.savetxt("data/estrellas.txt", datos)

print("Listo, archivo creado")
# Out:
# Listo, archivo creado

# %%
from pylab import scatter,xlabel,ylabel,xlim,ylim,show

data = np.loadtxt("data/estrellas.txt",float)

x = data[:,0]
y = data [:,1]

plt.figure(figsize=(9,6))

scatter(x,y)

plt.title("Scatter Plot de datos esperimentales",fontsize=15)

xlabel("Temperatura",fontsize=13)
ylabel("Magnitud",fontsize=13)
xlim(0, 13000)
ylim(-5,20)

plt.axhline(y = 0.0, xmin = 0.0, color = 'black')
plt.axvline(x = 0.0, ymin = 0.0, color = 'black')
plt.grid()

# %% [markdown]
# <!-- ### Gráficas en 2D -->
# ### Density plots

# %%
import numpy as np
import os
os.makedirs("data", exist_ok=True)

# Creamos un dato circular tipo densidad
# Es como un anillo
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
R = np.sqrt(X**2 + Y**2)
circular = np.exp(-(R-2)**2 / 0.5)  # anillo de radio 2

np.savetxt("data/circular.txt", circular)
print("circular.txt creado")
# Out:
# circular.txt creado

# %%
from pylab import imshow,gray,show

plt.figure(figsize=(9,6))

data = np.loadtxt("data/circular.txt",float)
imshow(data)

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt("data/circular.txt", float)
plt.imshow(data, origin="lower")
plt.gray()

# %%
import numpy as np
import matplotlib.pyplot as plt
import shutil

# copiamos el que ya tienes en data/ a la raiz
shutil.copy("data/circular.txt", "circular.txt")

data = np.loadtxt("circular.txt", float)
plt.imshow(data, origin="lower")
plt.gray()

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt("circular.txt", float)

plt.imshow(data, origin="lower")
plt.gray()
plt.title("Density plot - circular")
plt.colorbar(label="densidad")

# %%
data = np.loadtxt("circular.txt",float)
imshow(data,origin="lower")
plt.gray()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1515/442306794.py in <cell line: 0>()
# ----> 1 data = np.loadtxt("circular.txt",float)
#       2 imshow(data,origin="lower")
#       3 plt.gray()
#
# /usr/local/lib/python3.13/dist-packages/numpy/lib/_npyio_impl.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1395         delimiter = delimiter.decode('latin1')
#    1396
# -> 1397     arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1398                 converters=converters, skiplines=skiprows, usecols=usecols,
#    1399                 unpack=unpack, ndmin=ndmin, encoding=encoding,
#
# /usr/local/lib/python3.13/dist-packages/numpy/lib/_npyio_impl.py in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#    1010             fname = os.fspath(fname)
#    1011         if isinstance(fname, str):
# -> 1012             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1013             if encoding is None:
#    1014                 encoding = getattr(fh, 'encoding', 'latin1')
#
# /usr/local/lib/python3.13/dist-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     190
#     191     ds = DataSource(destpath)
# --> 192     return ds.open(path, mode, encoding=encoding, newline=newline)
#     193
#     194
#
# /usr/local/lib/python3.13/dist-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     527                                       encoding=encoding, newline=newline)
#     528         else:
# --> 529             raise FileNotFoundError(f"{path} not found.")
#     530
#     531
#
# FileNotFoundError: circular.txt not found.

# %%
imshow(data,origin="lower",extent=[0,10,0,5])
plt.gray()

# %%
imshow(data,origin="lower",extent=[0,10,0,5] ,aspect=2.0)

# %%
wavelength = 5.0
k = 2*mt.pi/wavelength
xi0 = 1.0
separation = 20.0      # Separacion de los centros en cm
side = 100.0           # lado del cuadro en cm
points = 500           # Numero de puntos de la cuadrucula a lo largo de cada lado
spacing = side/points  # Espaciado de puntos en cm


# Calculo de las posiciones de los centros de los corculos.
x1 = side/2 + separation/2
y1 = side/2
x2 = side/2 - separation/2
y2 = side/2

# arreglo para almacenar las alturas.
xi = np.empty([points,points],float)

# Calcula los valores en el arreglo.
for i in range(points):
    y = spacing*i
    for j in range(points):
        x = spacing*j
        r1 = mt.sqrt((x-x1)**2+(y-y1)**2)
        r2 = mt.sqrt((x-x2)**2+(y-y2)**2)
        xi[i,j] = xi0*mt.sin(k*r1) + xi0*mt.sin(k*r2)

# Hace la grfica
imshow(xi,origin="lower",extent=[0,side,0,side])
plt.gray()

# %% [markdown]
# ## Gráficas Interactivas
#
# Es posible ver gráficas de forma interactiva en Jupyter, mediante la biblioteca **_`ipywidgets`_** y el comando   con `%matplotlib widget`.

# %%
# !pip install ipympl
# Out:
# Collecting ipympl
#   Downloading ipympl-0.10.0-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: ipython<10 in /usr/local/lib/python3.13/dist-packages (from ipympl) (7.34.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /usr/local/lib/python3.13/dist-packages (from ipympl) (7.7.1)
# Requirement already satisfied: matplotlib<4,>=3.5.0 in /usr/local/lib/python3.13/dist-packages (from ipympl) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from ipympl) (2.1.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.13/dist-packages (from ipympl) (11.3.0)
# Requirement already satisfied: traitlets<6 in /usr/local/lib/python3.13/dist-packages (from ipympl) (5.7.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.13/dist-packages (from ipython<10->ipympl) (80.10.2)
# Collecting jedi>=0.16 (from ipython<10->ipympl)
#   Downloading jedi-0.20.0-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.13/dist-packages (from ipython<10->ipympl) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.13/dist-packages (from ipython<10->ipympl) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from ipython<10->ipympl) (3.0.53)
# Requirement already satisfied: pygments in /usr/local/lib/python3.13/dist-packages (from ipython<10->ipympl) (2.21.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.13/dist-packages (from ipython<10->ipympl) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.13/dist-packages (from ipython<10->ipympl) (0.2.2)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.13/dist-packages (from ipython<10->ipympl) (4.9.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.13/dist-packages (from ipywidgets<9,>=7.6.0->ipympl) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.13/dist-packages (from ipywidgets<9,>=7.6.0->ipympl) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.13/dist-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.17)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib<4,>=3.5.0->ipympl) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib<4,>=3.5.0->ipympl) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib<4,>=3.5.0->ipympl) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib<4,>=3.5.0->ipympl) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib<4,>=3.5.0->ipympl) (26.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib<4,>=3.5.0->ipympl) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib<4,>=3.5.0->ipympl) (2.9.0.post0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (7.4.9)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (6.5.7)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.13/dist-packages (from jedi>=0.16->ipython<10->ipympl) (0.8.7)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.13/dist-packages (from pexpect>4.3->ipython<10->ipympl) (0.7.0)
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.13/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<10->ipympl) (0.8.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.7->matplotlib<4,>=3.5.0->ipympl) (1.17.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.13/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (6.5.7)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.13/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.13/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (5.9.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (3.1.6)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (25.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (5.11.1)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (7.17.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.26.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.3.3)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.13/dist-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (4.11.7)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.13/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.13/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (6.4.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (3.3.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.13/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (2.22.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.13/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (4.26.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.13/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (26.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.13/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.6.1)
# Requirement already satisfied: tinycss2>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.5.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (2026.6.3)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.13/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (2.20.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (2.1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (4.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (3.0)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (4.14.2)
# Requirement already satisfied: jupyter-events>=0.11.0 in /usr/local/lib/python3.13/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.13/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.5.4)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.13/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.9.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.13/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (3.19)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.13/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (4.2.0)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.13/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.13/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.13/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.1.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (25.10.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.13/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.13/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.4.0)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.13/dist-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (2026.3)
# Downloading ipympl-0.10.0-py3-none-any.whl (519 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.0/519.0 kB 12.6 MB/s eta 0:00:00
# Downloading jedi-0.20.0-py2.py3-none-any.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 87.8 MB/s eta 0:00:00
# Installing collected packages: jedi, ipympl
# Successfully installed ipympl-0.10.0 jedi-0.20.0

# %%
from ipywidgets import *
# %matplotlib widget
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1515/3128353771.py in <cell line: 0>()
#       1 from ipywidgets import *
# ----> 2 get_ipython().run_line_magic('matplotlib', 'widget')
#
# /usr/local/lib/python3.13/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2416                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2417             with self.builtin_trap:
# -> 2418                 result = fn(*args, **kwargs)
#    2419             return result
#    2420
#
# <decorator-gen-101> in matplotlib(self, line)
#
# /usr/local/lib/python3.13/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.13/dist-packages/IPython/core/magics/pylab.py in matplotlib(self, line)
#      97             print("Available matplotlib backends: %s" % backends_list)
#      98         else:
# ---> 99             gui, backend = self.shell.enable_matplotlib(args.gui.lower() if isinstance(args.gui, str) else args.gui)
#     100             self._show_matplotlib_backend(args.gui, backend)
#     101
#
# /usr/local/lib/python3.13/dist-packages/IPython/core/interactiveshell.py in enable_matplotlib(self, gui)
#    3645                 gui, backend = pt.find_gui_and_backend(self.pylab_gui_select)
#    3646
# -> 3647         pt.activate_matplotlib(backend)
#    3648         configure_inline_support(self, backend)
#    3649
#
# /usr/local/lib/python3.13/dist-packages/IPython/core/pylabtools.py in activate_matplotlib(backend)
#     350     # the rcParam to update. This needs to be set *before* the module
#     351     # magic of switch_backend().
# --> 352     matplotlib.rcParams['backend'] = backend
#     353
#     354     # Due to circular imports, pyplot may be only partially initialised
#
# /usr/local/lib/python3.13/dist-packages/matplotlib/__init__.py in __setitem__(self, key, val)
#     769                 cval = self.validate[key](val)
#     770             except ValueError as ve:
# --> 771                 raise ValueError(f"Key {key}: {ve}") from None
#     772             self._set(key, cval)
#     773         except KeyError as err:
#
# ValueError: Key backend: 'module://ipympl.backend_nbagg' is not a valid value for backend; supported values are ['gtk3agg', 'gtk3cairo', 'gtk4agg', 'gtk4cairo', 'macosx', 'nbagg', 'notebook', 'qtagg', 'qtcairo', 'qt5agg', 'qt5cairo', 'tkagg', 'tkcairo', 'webagg', 'wx', 'wxagg', 'wxcairo', 'agg', 'cairo', 'pdf', 'pgf', 'ps', 'svg', 'template', 'inline']

# %%
from ipywidgets import *
# %matplotlib widget
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1515/3128353771.py in <cell line: 0>()
#       1 from ipywidgets import *
# ----> 2 get_ipython().run_line_magic('matplotlib', 'widget')
#
# /usr/local/lib/python3.13/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2416                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2417             with self.builtin_trap:
# -> 2418                 result = fn(*args, **kwargs)
#    2419             return result
#    2420
#
# <decorator-gen-101> in matplotlib(self, line)
#
# /usr/local/lib/python3.13/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.13/dist-packages/IPython/core/magics/pylab.py in matplotlib(self, line)
#      97             print("Available matplotlib backends: %s" % backends_list)
#      98         else:
# ---> 99             gui, backend = self.shell.enable_matplotlib(args.gui.lower() if isinstance(args.gui, str) else args.gui)
#     100             self._show_matplotlib_backend(args.gui, backend)
#     101
#
# /usr/local/lib/python3.13/dist-packages/IPython/core/interactiveshell.py in enable_matplotlib(self, gui)
#    3645                 gui, backend = pt.find_gui_and_backend(self.pylab_gui_select)
#    3646
# -> 3647         pt.activate_matplotlib(backend)
#    3648         configure_inline_support(self, backend)
#    3649
#
# /usr/local/lib/python3.13/dist-packages/IPython/core/pylabtools.py in activate_matplotlib(backend)
#     350     # the rcParam to update. This needs to be set *before* the module
#     351     # magic of switch_backend().
# --> 352     matplotlib.rcParams['backend'] = backend
#     353
#     354     # Due to circular imports, pyplot may be only partially initialised
#
# /usr/local/lib/python3.13/dist-packages/matplotlib/__init__.py in __setitem__(self, key, val)
#     769                 cval = self.validate[key](val)
#     770             except ValueError as ve:
# --> 771                 raise ValueError(f"Key {key}: {ve}") from None
#     772             self._set(key, cval)
#     773         except KeyError as err:
#
# ValueError: Key backend: 'module://ipympl.backend_nbagg' is not a valid value for backend; supported values are ['gtk3agg', 'gtk3cairo', 'gtk4agg', 'gtk4cairo', 'macosx', 'nbagg', 'notebook', 'qtagg', 'qtcairo', 'qt5agg', 'qt5cairo', 'tkagg', 'tkcairo', 'webagg', 'wx', 'wxagg', 'wxcairo', 'agg', 'cairo', 'pdf', 'pgf', 'ps', 'svg', 'template', 'inline']

# %%
plt.figure(figsize=(9,7))

plt.plot(x,fx,color='olive', ls='-',lw=2,label='cos(x)')
plt.plot(x,fx1,color='#a41b81',marker='.',ms=9,ls='None',label='sen(x)')

plt.title("Funciones periodicas")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend(loc=2)

plt.axhline(y = 0.0, xmin = 0.0, color = 'black')
plt.axvline(x = 0.0, ymin = 0.0, color = 'black')
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-2*np.pi, 2*np.pi, 100)

plt.figure(figsize=(9,7))
plt.plot(x, np.cos(x), color='olive', ls='-', lw=2, label='cos(x)')
plt.plot(x, np.sin(x), color='#4d1b81', marker='.', ms=9, ls='None', label='sen(x)')

plt.title("Funciones periodicas")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend(loc=2)
plt.axhline(y=0, color='black')
plt.axvline(x=0, color='black')
plt.grid()
plt.show()

# %% [markdown]
# ### **Ejercicio:**
#
# Escribe un programa que lea el archivo `data/datos.dat` y guarde en una arreglo de `numpy` los datos de la primera columna y en otro diferente los datos de la segunda columna.
#
# Aunque la función `plot` está diseñada principalmente para hacer gráficos $xy$ estándar, se puede adaptar para otros tipos de gráficas también.

# %% [markdown]
# **a)** Grafica la llamada curva \defn{deltoide}, definida paramétricamente por las ecuaciones:
#
# <h4 align="center">
# $
#         x = 2 \cos \theta + \cos 2\theta, \qquad
#         y = 2 \sin \theta - \sin 2\theta,
# $
# </h4>
#
# donde $0\le\theta<2\pi$. Toma un conjunto de valores para $\theta$ entre $0$ y $2\pi$ y calcula $x(\theta)$ e $y(\theta)$ usando las ecuaciones anteriores, para posteriormente graficar $y$ como función de $x$.

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

os.makedirs('data', exist_ok=True)
if not os.path.exists('data/datos.dat'):
    datos_prueba = np.random.rand(50, 2) * 10
    np.savetxt('data/datos.dat', datos_prueba)

datos = np.loadtxt('data/datos.dat')
columna1 = datos[:, 0]
columna2 = datos[:, 1]

plt.scatter(columna1, columna2)
plt.title("Datos de data/datos.dat")
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

theta = np.linspace(0, 2*np.pi, 1000)
x = 2*np.cos(theta) + np.cos(2*theta)
y = 2*np.sin(theta) - np.sin(2*theta)

plt.figure(figsize=(6,6))
plt.plot(x, y, 'r-')
plt.title("a) Curva deltoide")
plt.axis('equal')
plt.grid(True)
plt.show()

# %% [markdown]
# **b)** Usando este mismo enfoque, se puede hacer una gráfica polar $r=f(\theta)$ para alguna función $f$ calculando $r$ para un rango de valores de $\theta$ y luego convirtiendo $r$ y $\theta$ a coordenadas cartesianas usando las ecuaciones estándar:
#
# <h4 align="center">$ x = r\cos\theta $ </h4>
#
# <h4 align="center">$ y = r\sin\theta  $ </h4>
#
#
# Utiliza este método para trazar la _espiral Galileana_: $\; r = \theta^2 \; \;$ para $0\le\theta\le10\pi$.

# %%
import numpy as np
import matplotlib.pyplot as plt

# 0 <= theta <= 10pi
theta = np.linspace(0, 10*np.pi, 1000)

# Espiral Galileana r = theta^2
r = theta**2

# Conversion de polar a cartesiana
x = r * np.cos(theta)
y = r * np.sin(theta)

plt.figure(figsize=(8,8))
plt.plot(x, y, color='#1a8a2a', lw=1.5)

plt.title("b) Espiral Galileana: r = θ²", fontsize=14)
plt.xlabel("x = r cos(θ)")
plt.ylabel("y = r sin(θ)")
plt.axhline(y=0, color='black', lw=0.5)
plt.axvline(x=0, color='black', lw=0.5)
plt.axis('equal') # importantisimo para que no se vea ovalada
plt.grid(True)
plt.show()

# %% [markdown]
# **c)** Con el mismo método, haz una gráfica polar de la _"función de Fey"_:
#
# <h4 align="center">
# $
#     r = e^{\cos\theta} - 2 \cos 4\theta + \sin^5 \frac{\theta}{12}
# $
# </h4>
#
# en el rango $0\le\theta\le24\pi$.

# %%
import numpy as np
import matplotlib.pyplot as plt

# 0 <= theta <= 24pi
theta = np.linspace(0, 24*np.pi, 10000)

# c) Funcion de Fey
r = np.exp(np.cos(theta)) - 2*np.cos(4*theta) + (np.sin(theta/12))**5

# Polar a cartesiana
x = r * np.cos(theta)
y = r * np.sin(theta)

plt.figure(figsize=(8,7))
plt.plot(x, y, color='#c4005b', lw=1.2)

plt.title("c) Función de Fey (mariposa)", fontsize=14)
plt.xlabel("x = r cos(θ)")
plt.ylabel("y = r sin(θ)")
plt.axhline(y=0, color='black', lw=0.3)
plt.axvline(x=0, color='black', lw=0.3)
plt.axis('equal')
plt.grid(True, alpha=0.3)
plt.show()
